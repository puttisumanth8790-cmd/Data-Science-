# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings 
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv(r"D:\Downloads\WA_Fn-UseC_-HR-Employee-Attrition.csv")
df=pd.DataFrame(data)
pd.set_option('display.max_columns', None)
print(df)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# ## Understanding your Dataset

# %%
df.head(1)
# Out:
#    Age Attrition BusinessTravel  DailyRate Department  DistanceFromHome  \
# 0   41       Yes  Travel_Rarely       1102      Sales                 1
#
#    Education EducationField  EmployeeCount  EmployeeNumber  \
# 0          2  Life Sciences              1               1
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2  Female          94               3         2
#
#            JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  MonthlyRate  \
# 0  Sales Executive                4        Single           5993        19479
#
#    NumCompaniesWorked Over18 OverTime  PercentSalaryHike  PerformanceRating  \
# 0                   8      Y      Yes                 11                  3
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                         1             80                 0
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# ...

# %%
df.tail(1)
# Out:
#       Age Attrition BusinessTravel  DailyRate              Department  \
# 1469   34        No  Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  EnvironmentSatisfaction Gender  HourlyRate  \
# 1469            2068                        2   Male          82
#
#       JobInvolvement  JobLevel                JobRole  JobSatisfaction  \
# 1469               4         2  Laboratory Technician                3
#
#      MaritalStatus  MonthlyIncome  MonthlyRate  NumCompaniesWorked Over18  \
# 1469       Married           4404        10228                   2      Y
#
#      OverTime  PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 1469       No                 12                  3                         1
#
#       StandardHours  StockOptionLevel  TotalWorkingYears  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df.nunique()
# Out:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1470, step=1)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
print(df.loc[:,["Age","Attrition"]])
print(df.loc[df["Age"]==45])
print(df.loc[df["Age"]==45,["OverTime",'JobRole']])
# Out:
#       Age Attrition
# 0      41       Yes
# 1      49        No
# 2      37       Yes
# 3      33        No
# 4      27        No
# ...   ...       ...
# 1465   36        No
# 1466   39        No
# 1467   27        No
# 1468   49        No
# 1469   34        No
#
# [1470 rows x 2 columns]
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 67     45        No      Travel_Rarely       1339  Research & Development
# 77     45        No      Travel_Rarely        193  Research & Development
# 141    45        No      Travel_Rarely       1316  Research & Development
# 153    45        No      Travel_Rarely        194  Research & Development
# 174    45        No      Travel_Rarely       1268                   Sales
# 194    45        No         Non-Travel       1195  Research & Development
# 218    45        No         Non-Travel       1052                   Sales
# 244    45        No      Travel_Rarely        252  Research & Development
# ...

# %%
df.iloc[0,1]
# Out:
# 'Yes'

# %%
print(df.iloc[0:10,0:2])
# Out:
#    Age Attrition
# 0   41       Yes
# 1   49        No
# 2   37       Yes
# 3   33        No
# 4   27        No
# 5   32        No
# 6   59        No
# 7   30        No
# 8   38        No
# 9   36        No

# %% [markdown]
# ## Filtering the Data
# 1. Boolean filtering
#        ↓
# 2. AND / OR / NOT
#        ↓
# 3. isin()
#        ↓
# 4. between()
#        ↓
# 5. isna() / notna()
#        ↓
# 6. loc[]
#        ↓
# 7. String filtering
#        ↓
# 8. Date filtering
#        ↓
# 9. query()
#        ↓
# 10. Combining filtering + groupby + aggregation

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df[(df.loc[:,"Age"]==45)&(df["Attrition"]=="Yes")]
# Out:
#      Age Attrition     BusinessTravel  DailyRate Department  DistanceFromHome  \
# 504   45       Yes  Travel_Frequently        306      Sales                26
# 913   45       Yes      Travel_Rarely       1449      Sales                 2
#
#      Education EducationField  EmployeeCount  EmployeeNumber  \
# 504          4  Life Sciences              1             684
# 913          3      Marketing              1            1277
#
#      EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 504                        1  Female         100               3         2
# 913                        1  Female          94               1         5
#
#              JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 504  Sales Executive                1       Married           4286
# 913          Manager                2        Single          18824
#
#      MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# ...

# %%
print(df[(df["Age"]<100)&(df["BusinessTravel"]=="Non_Travel")])
# Out:
# Empty DataFrame
# Columns: [Age, Attrition, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, EmployeeCount, EmployeeNumber, EnvironmentSatisfaction, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyIncome, MonthlyRate, NumCompaniesWorked, Over18, OverTime, PercentSalaryHike, PerformanceRating, RelationshipSatisfaction, StandardHours, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager]
# Index: []

# %%
df.query("Age==45").head(5)
# Out:
#      Age Attrition BusinessTravel  DailyRate              Department  \
# 67    45        No  Travel_Rarely       1339  Research & Development
# 77    45        No  Travel_Rarely        193  Research & Development
# 141   45        No  Travel_Rarely       1316  Research & Development
# 153   45        No  Travel_Rarely        194  Research & Development
# 174   45        No  Travel_Rarely       1268                   Sales
#
#      DistanceFromHome  Education EducationField  EmployeeCount  \
# 67                  7          3  Life Sciences              1
# 77                  6          4          Other              1
# 141                29          3        Medical              1
# 153                 9          3  Life Sciences              1
# 174                 4          2  Life Sciences              1
#
#      EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 67               86                        2    Male          59
# ...

# %%
df.iloc[65:68,0].isin([45]).head(5)
# Out:
# 65    False
# 66    False
# 67     True
# Name: Age, dtype: bool

# %%
df[df["Age"].between(45,46)].head()
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 29   46        No      Travel_Rarely        705                   Sales
# 48   46        No  Travel_Frequently       1211                   Sales
# 67   45        No      Travel_Rarely       1339  Research & Development
# 77   45        No      Travel_Rarely        193  Research & Development
# 79   46        No      Travel_Rarely        945         Human Resources
#
#     DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 29                 2          4      Marketing              1              38
# 48                 5          4      Marketing              1              62
# 67                 7          3  Life Sciences              1              86
# 77                 6          4          Other              1             101
# 79                 5          2        Medical              1             103
#
# ...

# %% [markdown]
# ## Checking the Missing values

# %%
print(df.isna().sum().head(5))
print(df.isnull().sum().head(5))
print(df[["Age","Attrition","BusinessTravel"]].notna().head())
print(df.notnull().sum())
# Out:
# Age               0
# Attrition         0
# BusinessTravel    0
# DailyRate         0
# Department        0
# dtype: int64
# Age               0
# Attrition         0
# BusinessTravel    0
# DailyRate         0
# Department        0
# dtype: int64
#     Age  Attrition  BusinessTravel
# 0  True       True            True
# 1  True       True            True
# 2  True       True            True
# 3  True       True            True
# 4  True       True            True
# Age                         1470
# Attrition                   1470
# BusinessTravel              1470
# DailyRate                   1470
# Department                  1470
# DistanceFromHome            1470
# Education                   1470
# EducationField              1470
# EmployeeCount               1470
# EmployeeNumber              1470
# EnvironmentSatisfaction     1470
# Gender                      1470
# HourlyRate                  1470
# JobInvolvement              1470
# JobLevel                    1470
# ...

# %%
df["Age"].duplicated().head(5)
print(df.loc[:,"Age"].duplicated().head(100))
print(df["Age"].drop_duplicates())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96     True
# 97     True
# 98    False
# 99     True
# Name: Age, Length: 100, dtype: bool
# 0      41
# 1      49
# 2      37
# 3      33
# 4      27
# 5      32
# 6      59
# 7      30
# 8      38
# 9      36
# 10     35
# 11     29
# 12     31
# 13     34
# 14     28
# 17     22
# 18     53
# 20     24
# 23     21
# 27     42
# 28     44
# 29     46
# 33     39
# 35     43
# 36     50
# 42     26
# 50     48
# 65     55
# 67     45
# 85     56
# 86     23
# 87     51
# 90     40
# 95     54
# 98     58
# 102    20
# 107    25
# 127    19
# 163    57
# 190    52
# 271    47
# 296    18
# 411    60
# Name: Age, dtype: int64

# %% [markdown]
# ## Grouping and Aggregation

# %%
df.head(5)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
df.groupby("BusinessTravel")["Age"].mean()
print(df.groupby("BusinessTravel")["Age"].agg(["mean","median","std"]))
# Out:
#                         mean  median       std
# BusinessTravel
# Non-Travel         36.620000    36.0  8.776624
# Travel_Frequently  36.454874    35.0  8.547541
# Travel_Rarely      37.092042    36.0  9.337414

# %%
df["Age"].apply(lambda x:x*1.10)
# Out:
# 0       45.1
# 1       53.9
# 2       40.7
# 3       36.3
# 4       29.7
#         ...
# 1465    39.6
# 1466    42.9
# 1467    29.7
# 1468    53.9
# 1469    37.4
# Name: Age, Length: 1470, dtype: float64
