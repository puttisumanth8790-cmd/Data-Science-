# %%
import pandas as pd

# %%
df=pd.read_excel("D:\Sumanth.xlsx")

# %%
df.head() # displaying first 5 rows of the dataframe
# Out:
#    StudentID       Name Gender  Age  Departement     City   Marks  \
# 0         101  Sumanth   Male     20         CSE  New York   85.0
# 1         102  Surendra  Male     21         MCE   London    75.0
# 2         103     Sunny  Male     22          DS   London    65.0
# 3         104    Bunny   Male     23         CSE     paris   30.0
# 4         105   sudheer  Male     24      MATHS   New York   84.0
#
#    Attendance  Grade
# 0         95.0     b
# 1         37.0     C
# 2         35.0     C
# 3         44.0     F
# 4         55.0     C

# %%
df.tail() #displaying last 5 rows of the dataframe
# Out:
#     StudentID          Name   Gender  Age  Departement     City   Marks  \
# 13         114     Lavanya   Female     33          DS     paris   69.0
# 14         115       Kavya   Female     34        MECL  New York   30.0
# 15         116     Surekha   Female     35         KDB   landon    38.0
# 16         117       Punith  Female     36        DJND  New York    NaN
# 17         118  Madhu babu     Male     37         NaN  New York   47.0
#
#     Attendance  Grade
# 13         64.0     C
# 14         34.0     F
# 15         54.0     F
# 16          NaN   NaN
# 17         46.0     F

# %%
df.info() #displaying the information about the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   StudentID    18 non-null     int64
#  1   Name         18 non-null     object
#  2   Gender       18 non-null     object
#  3   Age          18 non-null     int64
#  4   Departement  16 non-null     object
#  5   City         18 non-null     object
#  6   Marks        16 non-null     float64
#  7   Attendance   16 non-null     float64
#  8   Grade        16 non-null     object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 1.4+ KB

# %%
df.describe() #displaying the statistical summary of the dataframe
# Out:
#        StudentID        Age        Marks  Attendance
# count   18.000000  18.000000   16.000000    16.000000
# mean   109.500000  28.500000   64.437500    45.625000
# std      5.338539   5.338539   22.718476    18.571932
# min    101.000000  20.000000   30.000000     5.000000
# 25%    105.250000  24.250000   46.250000    36.500000
# 50%    109.500000  28.500000   65.000000    45.000000
# 75%    113.750000  32.750000   84.250000    51.000000
# max    118.000000  37.000000  100.000000    95.000000

# %%
''' Data flitering '''
# Out:
# ' Data flitering '

# %%
df[df["Age "]>25] # it give the age greater than 25
# Out:
#     StudentID          Name   Gender  Age  Departement     City   Marks  \
# 6          107       sunila  Female     26         DS   New York  100.0
# 7          108        sunil    Male     27         HI     berlin   65.0
# 8          109       sudha   Female     28        CSE     berlin   65.0
# 9          110      Bhavani  Female     29         NaN  New York    NaN
# 10         111     Bhargavi  Female     30      TELUGU     belin   89.0
# 11         112       Tommy     Male     31      CILIV   New York   44.0
# 12         113        Jerry  Female     32         CSE     paris   50.0
# 13         114     Lavanya   Female     33          DS     paris   69.0
# 14         115       Kavya   Female     34        MECL  New York   30.0
# 15         116     Surekha   Female     35         KDB   landon    38.0
# 16         117       Punith  Female     36        DJND  New York    NaN
# 17         118  Madhu babu     Male     37         NaN  New York   47.0
#
#     Attendance  Grade
# 6          45.0     b
# 7           5.0     C
# 8          30.0     C
# 9           NaN   NaN
# 10         50.0     b
# 11         45.0     F
# 12         46.0     F
# 13         64.0     C
# 14         34.0     F
# 15         54.0     F
# 16          NaN   NaN
# 17         46.0     F

# %%
df[(df["Age "]>25) &(df["Grade"]=="b")] #it give the age filtering and grade filtering
# Out:
#     StudentID       Name   Gender  Age  Departement     City   Marks  \
# 6          107    sunila  Female     26         DS   New York  100.0
# 10         111  Bhargavi  Female     30      TELUGU     belin   89.0
#
#     Attendance  Grade
# 6          45.0     b
# 10         50.0     b

# %%
'''Data Transformation'''
# Out:
# 'Data Transformation'

# %%
df["Age_after_5Years"]=df["Age "]+ 10

# %%
df.rename(columns={"Age ":"Student_Age"})
# Out:
#     StudentID          Name   Gender  Student_Age Departement     City   \
# 0          101     Sumanth     Male            20         CSE  New York
# 1          102     Surendra    Male            21         MCE   London
# 2          103        Sunny    Male            22          DS   London
# 3          104       Bunny     Male            23         CSE     paris
# 4          105      sudheer    Male            24      MATHS   New York
# 5          106     surekha   Female            25        CSE      paris
# 6          107       sunila  Female            26         DS   New York
# 7          108        sunil    Male            27         HI     berlin
# 8          109       sudha   Female            28        CSE     berlin
# 9          110      Bhavani  Female            29         NaN  New York
# 10         111     Bhargavi  Female            30      TELUGU     belin
# 11         112       Tommy     Male            31      CILIV   New York
# 12         113        Jerry  Female            32         CSE     paris
# 13         114     Lavanya   Female            33          DS     paris
# 14         115       Kavya   Female            34        MECL  New York
# 15         116     Surekha   Female            35         KDB   landon
# 16         117       Punith  Female            36        DJND  New York
# 17         118  Madhu babu     Male            37         NaN  New York
#
#     Marks  Attendance  Grade  Age_after_5Years
# 0    85.0         95.0     b                30
# 1    75.0         37.0     C                31
# 2    65.0         35.0     C                32
# 3    30.0         44.0     F                33
# 4    84.0         55.0     C                34
# 5    95.0         45.0     b                35
# 6   100.0         45.0     b                36
# 7    65.0          5.0     C                37
# 8    65.0         30.0     C                38
# 9     NaN          NaN   NaN                39
# 10   89.0         50.0     b                40
# 11   44.0         45.0     F                41
# 12   50.0         46.0     F                42
# 13   69.0         64.0     C                43
# 14   30.0         34.0     F                44
# 15   38.0         54.0     F                45
# 16    NaN          NaN   NaN                46
# 17   47.0         46.0     F                47

# %%
df.groupby("City ")["Marks"].mean()
# Out:
# City
# London      70.0
# New York    65.0
# belin       89.0
# berlin      65.0
# landon      38.0
# paris       61.0
# Name: Marks, dtype: float64

# %%
df.sort_values("Age ")
# Out:
#     StudentID          Name   Gender  Age  Departement     City   Marks  \
# 0          101     Sumanth     Male     20         CSE  New York   85.0
# 1          102     Surendra    Male     21         MCE   London    75.0
# 2          103        Sunny    Male     22          DS   London    65.0
# 3          104       Bunny     Male     23         CSE     paris   30.0
# 4          105      sudheer    Male     24      MATHS   New York   84.0
# 5          106     surekha   Female     25        CSE      paris   95.0
# 6          107       sunila  Female     26         DS   New York  100.0
# 7          108        sunil    Male     27         HI     berlin   65.0
# 8          109       sudha   Female     28        CSE     berlin   65.0
# 9          110      Bhavani  Female     29         NaN  New York    NaN
# 10         111     Bhargavi  Female     30      TELUGU     belin   89.0
# 11         112       Tommy     Male     31      CILIV   New York   44.0
# 12         113        Jerry  Female     32         CSE     paris   50.0
# 13         114     Lavanya   Female     33          DS     paris   69.0
# 14         115       Kavya   Female     34        MECL  New York   30.0
# 15         116     Surekha   Female     35         KDB   landon    38.0
# 16         117       Punith  Female     36        DJND  New York    NaN
# 17         118  Madhu babu     Male     37         NaN  New York   47.0
#
#     Attendance  Grade  Age_after_5Years
# 0          95.0     b                30
# 1          37.0     C                31
# 2          35.0     C                32
# 3          44.0     F                33
# 4          55.0     C                34
# 5          45.0     b                35
# 6          45.0     b                36
# 7           5.0     C                37
# 8          30.0     C                38
# 9           NaN   NaN                39
# 10         50.0     b                40
# 11         45.0     F                41
# 12         46.0     F                42
# 13         64.0     C                43
# 14         34.0     F                44
# 15         54.0     F                45
# 16          NaN   NaN                46
# 17         46.0     F                47

# %%
df.sort_values("Age ",ascending=False)
# Out:
#     StudentID          Name   Gender  Age  Departement     City   Marks  \
# 17         118  Madhu babu     Male     37         NaN  New York   47.0
# 16         117       Punith  Female     36        DJND  New York    NaN
# 15         116     Surekha   Female     35         KDB   landon    38.0
# 14         115       Kavya   Female     34        MECL  New York   30.0
# 13         114     Lavanya   Female     33          DS     paris   69.0
# 12         113        Jerry  Female     32         CSE     paris   50.0
# 11         112       Tommy     Male     31      CILIV   New York   44.0
# 10         111     Bhargavi  Female     30      TELUGU     belin   89.0
# 9          110      Bhavani  Female     29         NaN  New York    NaN
# 8          109       sudha   Female     28        CSE     berlin   65.0
# 7          108        sunil    Male     27         HI     berlin   65.0
# 6          107       sunila  Female     26         DS   New York  100.0
# 5          106     surekha   Female     25        CSE      paris   95.0
# 4          105      sudheer    Male     24      MATHS   New York   84.0
# 3          104       Bunny     Male     23         CSE     paris   30.0
# 2          103        Sunny    Male     22          DS   London    65.0
# 1          102     Surendra    Male     21         MCE   London    75.0
# 0          101     Sumanth     Male     20         CSE  New York   85.0
#
#     Attendance  Grade  Age_after_5Years
# 17         46.0     F                47
# 16          NaN   NaN                46
# 15         54.0     F                45
# 14         34.0     F                44
# 13         64.0     C                43
# 12         46.0     F                42
# 11         45.0     F                41
# 10         50.0     b                40
# 9           NaN   NaN                39
# 8          30.0     C                38
# 7           5.0     C                37
# 6          45.0     b                36
# 5          45.0     b                35
# 4          55.0     C                34
# 3          44.0     F                33
# 2          35.0     C                32
# 1          37.0     C                31
# 0          95.0     b                30

# %%
df["Date"] = pd.to_datetime(df["Age "])

# %%
df.head()
# Out:
#    StudentID       Name Gender  Age  Departement     City   Marks  \
# 0         101  Sumanth   Male     20         CSE  New York   85.0
# 1         102  Surendra  Male     21         MCE   London    75.0
# 2         103     Sunny  Male     22          DS   London    65.0
# 3         104    Bunny   Male     23         CSE     paris   30.0
# 4         105   sudheer  Male     24      MATHS   New York   84.0
#
#    Attendance  Grade  Age_after_5Years                          Date
# 0         95.0     b                30 1970-01-01 00:00:00.000000020
# 1         37.0     C                31 1970-01-01 00:00:00.000000021
# 2         35.0     C                32 1970-01-01 00:00:00.000000022
# 3         44.0     F                33 1970-01-01 00:00:00.000000023
# 4         55.0     C                34 1970-01-01 00:00:00.000000024

# %%
df["Age "].mean()
df["Age "].median()
df["Age "].std()
df["Age "].max()
df["Age "].min()
# Out:
# 20

# %%
df.head()
# Out:
#    StudentID       Name Gender  Age  Departement     City   Marks  \
# 0         101  Sumanth   Male     20         CSE  New York   85.0
# 1         102  Surendra  Male     21         MCE   London    75.0
# 2         103     Sunny  Male     22          DS   London    65.0
# 3         104    Bunny   Male     23         CSE     paris   30.0
# 4         105   sudheer  Male     24      MATHS   New York   84.0
#
#    Attendance  Grade  Age_after_5Years                          Date
# 0         95.0     b                30 1970-01-01 00:00:00.000000020
# 1         37.0     C                31 1970-01-01 00:00:00.000000021
# 2         35.0     C                32 1970-01-01 00:00:00.000000022
# 3         44.0     F                33 1970-01-01 00:00:00.000000023
# 4         55.0     C                34 1970-01-01 00:00:00.000000024
